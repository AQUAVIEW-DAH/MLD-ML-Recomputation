# %%
import xarray as xr

ds = xr.open_dataset("rtofs_glo_3dz_f054_6hrly_hvr_US_east.nc")
print(ds)
# Out:
# <xarray.Dataset> Size: 822MB
# Dimensions:      (MT: 1, Depth: 40, Y: 1710, X: 742)
# Coordinates:
#   * MT           (MT) datetime64[ns] 8B 2026-04-01T06:00:00
#     Date         (MT) float64 8B ...
#   * Depth        (Depth) float32 160B 0.0 2.0 4.0 6.0 ... 3e+03 4e+03 5e+03
#   * Y            (Y) int32 7kB 1 2 3 4 5 6 7 ... 1705 1706 1707 1708 1709 1710
#   * X            (X) int32 3kB 1 2 3 4 5 6 7 8 ... 736 737 738 739 740 741 742
#     Latitude     (Y, X) float32 5MB ...
#     Longitude    (Y, X) float32 5MB ...
# Data variables:
#     u            (MT, Depth, Y, X) float32 203MB ...
#     v            (MT, Depth, Y, X) float32 203MB ...
#     temperature  (MT, Depth, Y, X) float32 203MB ...
#     salinity     (MT, Depth, Y, X) float32 203MB ...
# Attributes:
#     Conventions:  CF-1.0
#     title:        HYCOM ATLb2.00
#     institution:  National Centers for Environmental Prediction
#     source:       HYCOM archive file
#     experiment:   93.1
#     history:      archv2ncdf3z

# %%
print(ds["temperature"])
print(ds["salinity"])
print(ds["u"])
print(ds["v"])
# Out:
# <xarray.DataArray 'temperature' (MT: 1, Depth: 40, Y: 1710, X: 742)> Size: 203MB
# [50752800 values with dtype=float32]
# Coordinates:
#   * MT         (MT) datetime64[ns] 8B 2026-04-01T06:00:00
#     Date       (MT) float64 8B ...
#   * Depth      (Depth) float32 160B 0.0 2.0 4.0 6.0 ... 3e+03 4e+03 5e+03
#   * Y          (Y) int32 7kB 1 2 3 4 5 6 7 ... 1705 1706 1707 1708 1709 1710
#   * X          (X) int32 3kB 1 2 3 4 5 6 7 8 ... 735 736 737 738 739 740 741 742
#     Latitude   (Y, X) float32 5MB ...
#     Longitude  (Y, X) float32 5MB ...
# Attributes:
#     standard_name:  sea_water_potential_temperature
#     units:          degC
#     valid_range:    [-2.103227 31.442707]
#     long_name:        temp [93.1H]
# <xarray.DataArray 'salinity' (MT: 1, Depth: 40, Y: 1710, X: 742)> Size: 203MB
# [50752800 values with dtype=float32]
# Coordinates:
#   * MT         (MT) datetime64[ns] 8B 2026-04-01T06:00:00
#     Date       (MT) float64 8B ...
#   * Depth      (Depth) float32 160B 0.0 2.0 4.0 6.0 ... 3e+03 4e+03 5e+03
#   * Y          (Y) int32 7kB 1 2 3 4 5 6 7 ... 1705 1706 1707 1708 1709 1710
#   * X          (X) int32 3kB 1 2 3 4 5 6 7 8 ... 735 736 737 738 739 740 741 742
#     Latitude   (Y, X) float32 5MB ...
#     Longitude  (Y, X) float32 5MB ...
# Attributes:
#     standard_name:  sea_water_salinity
#     units:          psu
#     valid_range:    [ 0.37335736 39.321007  ]
#     long_name:       salinity [93.1H]
# <xarray.DataArray 'u' (MT: 1, Depth: 40, Y: 1710, X: 742)> Size: 203MB
# [50752800 values with dtype=float32]
# Coordinates:
#   * MT         (MT) datetime64[ns] 8B 2026-04-01T06:00:00
#     Date       (MT) float64 8B ...
#   * Depth      (Depth) float32 160B 0.0 2.0 4.0 6.0 ... 3e+03 4e+03 5e+03
#   * Y          (Y) int32 7kB 1 2 3 4 5 6 7 ... 1705 1706 1707 1708 1709 1710
#   * X          (X) int32 3kB 1 2 3 4 5 6 7 8 ... 735 736 737 738 739 740 741 742
#     Latitude   (Y, X) float32 5MB ...
#     Longitude  (Y, X) float32 5MB ...
# Attributes:
#     standard_name:  eastward_sea_water_velocity
#     units:          m/s
#     valid_range:    [-1.9626542  2.489874 ]
#     long_name:       u-veloc. [93.1H]
# <xarray.DataArray 'v' (MT: 1, Depth: 40, Y: 1710, X: 742)> Size: 203MB
# [50752800 values with dtype=float32]
# Coordinates:
#   * MT         (MT) datetime64[ns] 8B 2026-04-01T06:00:00
#     Date       (MT) float64 8B ...
#   * Depth      (Depth) float32 160B 0.0 2.0 4.0 6.0 ... 3e+03 4e+03 5e+03
#   * Y          (Y) int32 7kB 1 2 3 4 5 6 7 ... 1705 1706 1707 1708 1709 1710
#   * X          (X) int32 3kB 1 2 3 4 5 6 7 8 ... 735 736 737 738 739 740 741 742
#     Latitude   (Y, X) float32 5MB ...
#     Longitude  (Y, X) float32 5MB ...
# Attributes:
#     standard_name:  northward_sea_water_velocity
#     units:          m/s
#     valid_range:    [-2.3583064  1.9028759]
#     long_name:       v-veloc. [93.1H]

# %%
print(ds["temperature"].attrs)
print(ds["salinity"].attrs)
# Out:
# {'standard_name': 'sea_water_potential_temperature', 'units': 'degC', 'valid_range': array([-2.103227, 31.442707], dtype=float32), 'long_name': '  temp [93.1H]'}
# {'standard_name': 'sea_water_salinity', 'units': 'psu', 'valid_range': array([ 0.37335736, 39.321007  ], dtype=float32), 'long_name': ' salinity [93.1H]'}

# %%
print(ds["temperature"].min().item(), ds["temperature"].max().item())
print(ds["salinity"].min().item(), ds["salinity"].max().item())
print(ds["u"].min().item(), ds["u"].max().item())
print(ds["v"].min().item(), ds["v"].max().item())
# Out:
# -2.103226900100708 31.442707061767578
# 0.373357355594635 39.321006774902344
# -1.9626542329788208 2.4898738861083984
# -2.358306407928467 1.9028759002685547

# %%
print(ds["temperature"].isnull().sum().item())
print(ds["salinity"].isnull().sum().item())
# Out:
# 31920976
# 31920976

# %%
i, j = 800, 300
profile = ds["temperature"].isel(MT=0, Y=i, X=j)

print(profile)
print(profile.values)
print(ds["Depth"].values)
# Out:
# <xarray.DataArray 'temperature' (Depth: 40)> Size: 160B
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#       dtype=float32)
# Coordinates:
#   * Depth      (Depth) float32 160B 0.0 2.0 4.0 6.0 ... 3e+03 4e+03 5e+03
#     MT         datetime64[ns] 8B 2026-04-01T06:00:00
#     Date       float64 8B ...
#     Y          int32 4B 801
#     X          int32 4B 301
#     Latitude   float32 4B ...
#     Longitude  float32 4B ...
# Attributes:
#     standard_name:  sea_water_potential_temperature
#     units:          degC
#     valid_range:    [-2.103227 31.442707]
#     long_name:        temp [93.1H]
# [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan]
# [0.00e+00 2.00e+00 4.00e+00 6.00e+00 8.00e+00 1.00e+01 1.20e+01 1.50e+01
#  2.00e+01 2.50e+01 3.00e+01 3.50e+01 4.00e+01 4.50e+01 5.00e+01 6.00e+01
#  7.00e+01 8.00e+01 9.00e+01 1.00e+02 1.25e+02 1.50e+02 2.00e+02 2.50e+02
#  3.00e+02 3.50e+02 4.00e+02 5.00e+02 6.00e+02 7.00e+02 8.00e+02 9.00e+02
#  1.00e+03 1.25e+03 1.50e+03 2.00e+03 2.50e+03 3.00e+03 4.00e+03 5.00e+03]

# %%
surf_temp = ds["temperature"].isel(MT=0, Depth=0)
print(surf_temp)
print(surf_temp.min().item(), surf_temp.max().item())
# Out:
# <xarray.DataArray 'temperature' (Y: 1710, X: 742)> Size: 5MB
# array([[25.244537, 25.175247, 25.319725, ..., 28.401482, 28.398552, 28.392313],
#        [25.24243 , 25.290556, 25.278753, ..., 28.37852 , 28.371817, 28.367128],
#        [25.196903, 25.218287, 25.180923, ..., 28.349989, 28.33954 , 28.334452],
#        ...,
#        [      nan,       nan,       nan, ...,       nan,       nan,       nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,       nan],
#        [      nan,       nan,       nan, ...,       nan,       nan,       nan]],
#       shape=(1710, 742), dtype=float32)
# Coordinates:
#   * Y          (Y) int32 7kB 1 2 3 4 5 6 7 ... 1705 1706 1707 1708 1709 1710
#   * X          (X) int32 3kB 1 2 3 4 5 6 7 8 ... 735 736 737 738 739 740 741 742
#     Latitude   (Y, X) float32 5MB ...
#     Longitude  (Y, X) float32 5MB ...
#     MT         datetime64[ns] 8B 2026-04-01T06:00:00
#     Date       float64 8B ...
#     Depth      float32 4B 0.0
# Attributes:
#     standard_name:  sea_water_potential_temperature
#     units:          degC
#     valid_range:    [-2.103227 31.442707]
#     long_name:        temp [93.1H]
# -1.9736182689666748 31.442707061767578

# %%
import numpy as np
surf_temp = ds["temperature"].isel(MT=0, Depth=0)
valid = surf_temp.notnull()

# get first valid point
yx = np.argwhere(valid.values)
i, j = yx[0]
print(i, j)

profile = ds["temperature"].isel(MT=0, Y=i, X=j)
print(profile.values)
print(ds["Latitude"].isel(Y=i, X=j).item(), ds["Longitude"].isel(Y=i, X=j).item())
# Out:
# 0 0
# [25.244537  25.135551  25.064514  24.9052    24.722418  24.624249
#  24.545927  24.430042  24.138973  23.603842  23.121267  22.198387
#  20.89127   20.160765  19.538704  18.646637  17.991024  17.381985
#  16.586918  16.099073  14.832509  14.319991  13.24104   11.914779
#  11.124073  10.333368   9.443416   7.8728943  6.780668   6.1563272
#   5.5680532  4.9878645  4.512905   3.580922   3.066676   2.1752555
#   1.9523959  1.8971859        nan        nan]
# 0.0 -100.0

# %%
import numpy as np

def compute_mld_temp_threshold(depth, temp, ref_depth=10.0, delta_t=0.2):
    depth = np.asarray(depth, dtype=float)
    temp = np.asarray(temp, dtype=float)

    mask = np.isfinite(depth) & np.isfinite(temp)
    depth = depth[mask]
    temp = temp[mask]

    if len(depth) == 0:
        return None

    order = np.argsort(depth)
    depth = depth[order]
    temp = temp[order]

    if ref_depth < depth.min() or ref_depth > depth.max():
        return None

    tref = np.interp(ref_depth, depth, temp)
    target = tref - delta_t

    for k in range(len(depth)):
        if depth[k] <= ref_depth:
            continue
        if temp[k] <= target:
            if k == 0:
                return float(depth[k])
            z1, z2 = depth[k - 1], depth[k]
            t1, t2 = temp[k - 1], temp[k]

            if np.isclose(t1, t2):
                return float(z2)

            return float(z1 + (target - t1) * (z2 - z1) / (t2 - t1))

    return None

# %%
depth = ds["Depth"].values
temp = profile.values

mld = compute_mld_temp_threshold(depth, temp)
print("MLD at this point:", mld)
# Out:
# MLD at this point: 15.099525569447708

# %%
import numpy as np

def find_nearest_valid_point(ds, lat, lon):
    lats = ds["Latitude"].values
    lons = ds["Longitude"].values
    surf = ds["temperature"].isel(MT=0, Depth=0).values

    valid = np.isfinite(surf) & np.isfinite(lats) & np.isfinite(lons)
    if not np.any(valid):
        raise ValueError("No valid ocean points found in dataset")

    # simple squared-distance in lat/lon space
    dist2 = (lats - lat)**2 + (lons - lon)**2
    dist2[~valid] = np.inf

    i, j = np.unravel_index(np.argmin(dist2), dist2.shape)
    return i, j

# %%
def compute_mld_temp_threshold(depth, temp, ref_depth=10.0, delta_t=0.2):
    depth = np.asarray(depth, dtype=float)
    temp = np.asarray(temp, dtype=float)

    mask = np.isfinite(depth) & np.isfinite(temp)
    depth = depth[mask]
    temp = temp[mask]

    if len(depth) == 0:
        return None

    order = np.argsort(depth)
    depth = depth[order]
    temp = temp[order]

    if ref_depth < depth.min() or ref_depth > depth.max():
        return None

    tref = np.interp(ref_depth, depth, temp)
    target = tref - delta_t

    for k in range(len(depth)):
        if depth[k] <= ref_depth:
            continue
        if temp[k] <= target:
            z1, z2 = depth[k-1], depth[k]
            t1, t2 = temp[k-1], temp[k]
            if np.isclose(t1, t2):
                return float(z2)
            return float(z1 + (target - t1) * (z2 - z1) / (t2 - t1))

    return None

# %%
def get_model_mld(ds, lat, lon):
    i, j = find_nearest_valid_point(ds, lat, lon)
    profile = ds["temperature"].isel(MT=0, Y=i, X=j).values
    depth = ds["Depth"].values

    mld = compute_mld_temp_threshold(depth, profile)

    return {
        "query_lat": lat,
        "query_lon": lon,
        "grid_lat": float(ds["Latitude"].isel(Y=i, X=j).item()),
        "grid_lon": float(ds["Longitude"].isel(Y=i, X=j).item()),
        "time": str(ds["MT"].isel(MT=0).values),
        "mld_m": mld,
        "y_index": int(i),
        "x_index": int(j),
    }

# %%
result = get_model_mld(ds, 28.5, -88.2)
print(result)
# Out:
# {'query_lat': 28.5, 'query_lon': -88.2, 'grid_lat': 28.505590438842773, 'grid_lon': -88.1600341796875, 'time': '2026-04-01T06:00:00.000000000', 'mld_m': 16.964939046752814, 'y_index': 372, 'x_index': 148}
